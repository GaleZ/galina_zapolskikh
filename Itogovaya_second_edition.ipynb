# %%
import pandas as pd
data = pd.read_csv('HR.csv')
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
sum(satisfaction_level)
# Out:
# 9191.890000000014

# %%
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
#Рассчитать основные статистики для переменных:среднее,
#это сумма всех параметров,деленная на число объектов с данным параметром. 
avg_satisfaction=9191.890000000014/14999
print(avg_satisfaction)
# Out:
# 0.6128335222348166

# %%
#медиана
import statistics
print('Медиана: ', statistics.median(satisfaction_level))
# Out:
# Медиана:  0.64

# %%
#мода
print('Значение моды: ', statistics.mode(satisfaction_level))
# Out:
# Значение моды:  0.1

# %%
#мин/макс
min(satisfaction_level)
# Out:
# 0.09

# %%
max(satisfaction_level)
# Out:
# 1.0

# %%
#сред.отклонение 
print('Среднее отклонение: ', statistics.pstdev(satisfaction_level))
# Out:
# Среднее отклонение:  0.2486223626820733

# %%
correlation_matrix = data.corr()
print(correlation_matrix)

# %%
import matplotlib.pyplot as plt

# %%
#пришлось еще раз скопипастить, потому что всё зависло и команда data.plot после сейва и перезапуска выдавала name data is not defined
import pandas as pd
data = pd.read_csv('HR.csv')
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
##3.Рассчитать и визуализировать корреляционную матрицу для переменных.
data.plot()

# %%
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
#4.Визуализировать несколько взаимосвязей между переменными.
plt.plot(data['satisfaction_level'])
plt.plot(data['time_spend_company'])

# %%
import pandas as pd
data = pd.read_csv('HR.csv')

# %%
import statistics
from scipy import stats

# %%
#5.С использованием t-test статистики проверить взаимосвязи между несколькими переменными.
#Если я правильно поняла и satisfaction_level - это субъективный уровень удовлетворенности сотрудника своей работой, 
#а last_evaluation - это объективная оценка качества его работы, взятая за некий самый крайний отчетный период, то попробую так:
s_level=data['satisfaction_level']
last_ev=data['last_evaluation']
stats.ttest_ind(s_level, last_ev)
# Out:
# Ttest_indResult(statistic=-41.89868154070206, pvalue=0.0)

# %%
#а вот с расшифровкой результатов, если честно, непонятки. 
#Думаю, что pvalue=0.0 означает, что связи/зависимости между двумя анализируемыми параметрами нет.

# %%
#6.Рассчитать сколько работников работает в каждом департаменте.
data.groupby('sales').aggregate(sum)
#первая попытка как-то не задалась, не знаю откуда достать цифру по работникам в каждом департаменте
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# sales
# IT                       758.46           879.55            4683
# RandD                    487.80           560.44            3033
# accounting               446.51           550.49            2934
# hr                       442.52           523.84            2701
# management               391.45           456.12            2432
# marketing                530.76           614.23            3164
# product_mng              558.91           644.71            3434
# sales                   2543.81          2938.23           15634
# support                 1378.19          1611.81            8479
# technical               1653.48          1961.39           10548
#
#              average_montly_hours  time_spend_company  Work_accident  left  \
# sales
# IT                         248119                4256            164   273
# RandD                      158030                2650            134   121
# ...

# %%
#6.Рассчитать сколько работников работает в каждом департаменте.
departments=data[['sales']].copy()

# %%
departments.groupby('sales').aggregate(sum)
#не знаю, как цифры вывести
# Out:
# Empty DataFrame
# Columns: []
# Index: [IT, RandD, accounting, hr, management, marketing, product_mng, sales, support, technical]

# %%
import matplotlib.pyplot as plt

# %%
#7.Показать распределение сотрудников по зарплатам
plt.plot(data['salary'])

# %%
#8.Показать распределение сотрудников по зарплатам совместно с департаментами.
plt.bar('salary', 'sales')
# Out:
# <BarContainer object of 1 artists>

# %%
import pandas as pd
data = pd.read_csv('HR.csv')
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
#9.Сколько сотрудников покинули компанию.
sum(left)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-2a50e1a3d922> in <module>
#       1 #9.Сколько сотрудников покинули компанию.
# ----> 2 sum(left)
#
# NameError: name 'left' is not defined

# %%
#10.Проверить несколько гипотез для данных, чтобы понять почему сотрудники покидают компанию.
import seaborn as sns

# %%
sns_plot=sns.pairplot(
    data[['satisfaction_level', 'left']])
sns_plot
#попыталась связать число ушедших сотрудников с уровнем субъективной удовлетворенности работой

# %%
sns_plot=sns.pairplot(
    data[['last_evaluation', 'left']])
sns_plot
#попыталась связать число ушедших сотрудников с объективными оценками качества их работы

# %%
#11.Загрузить результат (в формате .ipynb ноутбука) в репозиторий. Разместить ссылку на репозиторий в Личном кабинете
